# %% [markdown]
# # Feature Engineering 1.1.1 Notebook

# %%
from src.utils import data_utils

# %%
data_utils.load_data("../data/interim/eda_1_0_1_df.pkl")
# Out:
#       (participants_age, modified_dem_0110) (participants_sex, dem_0500)  \
# 0                                        58                            F
# 1                                        30                            F
# 2                                        30                            F
# 3                                        42                            M
# 4                                        36                            M
# ...                                     ...                          ...
# 1876                                     77                            M
# 1877                                     32                            F
# 1878                                     71                            F
# 1879                                     71                            F
# 1880                                     30                            M
#
#       (height_in_inches, dem_0610)  (weight_in_pounds, dem_0700)  \
# ...
